# %%
#import needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
old = pd.read_csv('2003-2015dat.csv')
new = pd.read_csv('2015-2019dat.csv')

# %%
old.head()
# Out:
#    Unnamed: 0 REGION TYPE REGION  YEAR  WEEK  TOTAL SPECIMENS  \
# 0           0    National      X  2003    40             1430
# 1           1    National      X  2003    41             1682
# 2           2    National      X  2003    42             2176
# 3           3    National      X  2003    43             2568
# 4           4    National      X  2003    44             2753
#
#    PERCENT POSITIVE  TOTAL A  TOTAL B
# 0           1.53846       21        1
# 1           4.57788       77        0
# 2          11.62680      252        1
# 3          17.83490      454        4
# 4          19.43330      535        0

# %%
new.head()
# Out:
#    Unnamed: 0 REGION TYPE REGION  YEAR  WEEK  TOTAL SPECIMENS  \
# 0           0    National      X  2015    40            12029
# 1           1    National      X  2015    41            13111
# 2           2    National      X  2015    42            13441
# 3           3    National      X  2015    43            13537
# 4           4    National      X  2015    44            14687
#
#    PERCENT POSITIVE  TOTAL A  TOTAL B  PERCENT A  PERCENT B
# 0           1.05578       84       43   0.698312   0.357469
# 1           1.29662      116       54   0.884753   0.411868
# 2           1.10855       97       52   0.721672   0.386876
# 3           1.10807       98       52   0.723942   0.384132
# 4           1.12344       97       68   0.660448   0.462994

# %%
dadat = pd.concat([old,new],axis=0,sort=False)

# %%
dadat=dadat.drop(['Unnamed: 0'],axis=1)

# %%
dadat.reset_index(drop=True,inplace=True)

# %%
dadat
# Out:
#     REGION TYPE REGION  YEAR  WEEK  TOTAL SPECIMENS  PERCENT POSITIVE  \
# 0      National      X  2003    40             1430          1.538460
# 1      National      X  2003    41             1682          4.577880
# 2      National      X  2003    42             2176         11.626800
# 3      National      X  2003    43             2568         17.834900
# 4      National      X  2003    44             2753         19.433300
# 5      National      X  2003    45             3553         24.261200
# 6      National      X  2003    46             4595         28.095800
# 7      National      X  2003    47             5942         33.120200
# 8      National      X  2003    48             6479         34.743000
# 9      National      X  2003    49             9598         34.059200
# 10     National      X  2003    50            12422         32.925500
# 11     National      X  2003    51            11783         30.798600
# ...

# %%
dadat.to_csv('final_truth_dat.csv')
