# %%
#import needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
data_prevflu = pd.read_csv('word_preventflu.csv')
data_flu = pd.read_csv('word_flu.csv')
data_cdc = pd.read_csv('CDCDat/ILINet.csv')
data_flu.head()
# Out:
#         Category: All categories
# Month       flu: (United States)
# 2004-01                        8
# 2004-02                        6
# 2004-03                        3
# 2004-04                        2

# %%
data_flu = data_flu.drop(['Month'])

# %%
data_flu.head()
# Out:
#         Category: All categories
# 2004-01                        8
# 2004-02                        6
# 2004-03                        3
# 2004-04                        2
# 2004-05                        2

# %%
data_flu.reset_index(drop=True,inplace=True)

# %%
data_flu.head()
# Out:
#   Category: All categories
# 0                        8
# 1                        6
# 2                        3
# 3                        2
# 4                        2

# %%
data_cdc = data_cdc[data_cdc['YEAR']==2004]

# %%
data_cdc
# Out:
#    REGION TYPE REGION  YEAR  WEEK  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  \
# 14    National      X  2004     1        2.891290         2.418330     1930
# 15    National      X  2004     2        2.104290         1.809060     1679
# 16    National      X  2004     3        1.886960         1.712020     1721
# 17    National      X  2004     4        1.776600         1.542500     1487
# 18    National      X  2004     5        1.460010         1.437870     1454
# 19    National      X  2004     6        1.377870         1.324270     1420
# 20    National      X  2004     7        1.305320         1.307260     1301
# 21    National      X  2004     8        1.086910         1.036980      956
# 22    National      X  2004     9        0.991888         1.010320      925
# 23    National      X  2004    10        1.027650         1.052490      878
# 24    National      X  2004    11        1.057900         1.020090      730
# ...

# %%
weekly_flu_dat = pd.DataFrame()
weekly_prevdat = pd.DataFrame()
for i in range(len(data_flu)):
    val = data_flu['Category: All categories'].iloc[i]
    val2 = data_prevflu['Category: All categories'].iloc[i]
    for j in range(4):
        weekly_flu_dat=weekly_flu_dat.append(pd.DataFrame(np.array([val])))
        weekly_prevdat=weekly_prevdat.append(pd.DataFrame(np.array([val2])))

# %%
weekly_flu_dat.reset_index(drop=True,inplace=True)
weekly_prevdat.reset_index(drop=True,inplace=True)
weekly_prevdat = weekly_prevdat.drop([0,1,2,3])

# %%
weekly_flu_dat = weekly_flu_dat.iloc[:52,:]
weekly_prevdat = weekly_prevdat.iloc[:52,:]

# %%
weekly_prevdat
# Out:
#      0
# 4    4
# 5    4
# 6    4
# 7    4
# 8    6
# 9    6
# 10   6
# 11   6
# 12   6
# 13   6
# 14   6
# 15   6
# 16   0
# 17   0
# 18   0
# 19   0
# 20   6
# 21   6
# 22   6
# 23   6
# 24   0
# 25   0
# 26   0
# 27   0
# 28   2
# 29   2
# 30   2
# 31   2
# 32   2
# 33   2
# 34   2
# 35   2
# 36   2
# 37   2
# 38   2
# 39   2
# 40  12
# 41  12
# 42  12
# 43  12
# 44   4
# 45   4
# 46   4
# 47   4
# 48   5
# 49   5
# 50   5
# 51   5
# 52   6
# 53   6
# 54   6
# 55   6

# %%
x=np.arange(0,52)
y=weekly_flu_dat.iloc[:,0]
arr=np.array([y])
for i in range(len(y)):
    y[i]=int(y[i])*100

# %%
weekly_prevdat.reset_index(drop=True,inplace=True)
z=weekly_prevdat.iloc[:,0]
arr=np.array([z])
for i in range(len(z)):
    z[i]=int(z[i])*200

# %%
plt.plot(x,y)
y=data_cdc['ILITOTAL']
plt.plot(x,z)
plt.plot(x,y)
plt.title('Searches for \'prevent flu\',\'flu\' and Influenza cases 2004')
# Out:
# Text(0.5, 1.0, "Searches for 'prevent flu','flu' and Influenza cases 2004")
