# %%
import numpy as np
import pandas as pd

# %%
x = pd.read_csv('x.csv')
y = pd.read_csv('y.csv')

# %%
x = x.drop(columns='518')

# %%
y = y.drop(columns='Unnamed: 0')

# %%
temp = pd.DataFrame()
temp=temp.append([2527])
for i in range(len(x)):
    temp=temp.append([x['2527.0'][i]])

# %%
temp
# Out:
#           0
# 0    2527.0
# 0    2209.0
# 0    1910.0
# 0    1668.0
# 0    1474.0
# 0    1127.0
# 0     773.0
# 0     610.0
# 0     527.0
# 0     384.0
# 0     308.0
# 0     226.0
# 0     194.0
# 0     178.0
# 0     152.0
# 0     121.0
# 0     129.0
# 0      99.0
# 0      86.0
# 0      73.0
# 0      73.0
# 0      93.0
# 0      81.0
# 0      98.0
# 0     100.0
# 0     139.0
# 0     148.0
# 0     198.0
# 0     167.0
# 0     202.0
# ..      ...
# 0     189.0
# 0     166.0
# 0     173.0
# 0     210.0
# 0     363.0
# 0     366.0
# 0     332.0
# 0     415.0
# 0     476.0
# 0     260.0
# 0     327.0
# 0     359.0
# 0     555.0
# 0     777.0
# 0    1489.0
# 0    2124.0
# 0    3479.0
# 0    3870.0
# 0    4885.0
# 0    7250.0
# 0   12246.0
# 0   17213.0
# 0   15264.0
# 0   13977.0
# 0   15674.0
# 0   17777.0
# 0   21202.0
# 0   20931.0
# 0   19454.0
# 0   11249.0
#
# [259 rows x 1 columns]

# %%
x2 = np.array(temp).reshape(1,-1)

# %%
np.polyfit(x2,y,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-ac96a1346492> in <module>
# ----> 1 np.polyfit(x2,y,1)
#
# /anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     594         raise ValueError("expected deg >= 0")
#     595     if x.ndim != 1:
# --> 596         raise TypeError("expected 1D vector for x")
#     597     if x.size == 0:
#     598         raise TypeError("expected non-empty vector for x")
#
# TypeError: expected 1D vector for x

# %%
y.shape
# Out:
# (259, 1)
